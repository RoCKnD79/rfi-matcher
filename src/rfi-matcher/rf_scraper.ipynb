# %% [markdown]
# ## Imports

# %%
from urllib.request import urlopen
import json
import pandas as pd

# url = "https://data.nrao.edu/archive-service/restapi_product_details_view?sdm_id=25B-104.sb49474829.eb49602275.60965.561376909725"

# %% [markdown]
# ## Helper Functions

# %%
def get_html(url):
    '''
    Returns json data read from the url given in parameter    
    '''
    page = urlopen(url)

    html_bytes = page.read()
    html = html_bytes.decode("utf-8")

    return json.loads(html)

# %% [markdown]
# ## Scraping NRAO Data Archive

# %% [markdown]
# The following code extracts the table data from the NRAO Data Archive Portal: https://data.nrao.edu/portal/#/
#
# It fetches the json request the web page makes the list of latest projects. It then looks more into the details of the observations performed in each project, in particular the frequency bands in which the observations were performed.

# %%
START = 0
NUM_ROWS = 25

NRAO_PORTAL_URL = f"https://data.nrao.edu/archive-service/restapi_get_eb_project_view?start={START}&rows={NUM_ROWS}&sort=proj_stop%20desc"

# Read list of projects from NRAO data archive portal
nrao_portal_data = get_html(NRAO_PORTAL_URL)

# %%
# Extract list of project IDs
projects = nrao_portal_data["project_dict"]["projects"]
pd_projects = pd.DataFrame(projects)
print(projects)

project_codes = [project["project_code"] for project in projects if "project_code" in project]
print(project_codes)


public_projects = pd_projects[pd_projects["data_rights"].apply(lambda x: x == "PUBLIC")]
print("\nList of public projects:\n", public_projects["project_code"])
# Out:
# [{'id': 'nrao:623334', 'eb_id': 623334, 'sci_prod_locator': 'uid://evla/execblock/4edace58-af9f-4123-9239-aba6f6369549', 'obs_id': '25B-250.sb49363256.eb49611267.60969.423685601854', 'schedBlockName': None, 'filegroup_id': None, 'legacy_id': 'AB1981', 'project_code': '25B-250', 'title': 'PEARRLS: the Proplyd EVLA/ALMA Radio Recombination Line Survey', 'abstract': 'Most Sun-like stars form in clusters, where protoplanetary disks are externally photoevaporated by nearby massive stars. While previous studies of the Orion "proplyds" have shed light on the prevalence of external photoevaporation in typical star-forming environments, there is still much we do not know about the effects of external photoevaporation on planet formation. We propose to use joint VLA K-band, VLA Ka-band, and ALMA Band 4 observations of hydrogen (H) and helium (He) radio recombination lines (RRLs) to conduct a detailed study of the ionized gas that is ejected off photoevaporating disks. We will target 17 proplyds whose RRL emission was recently detected for the first time using ALMA Band 3. By probing RRLs at longer (VLA) and shorter (ALMA Band 4) wavelengths, we will robustly measure the densities, temperatures, and helium abundances of proplyd ionization fronts. With these measurements, we will determine 1) the typical mass-loss rates, lifetimes, and chemical compositions of photoevaporating disks, and 2) whether the Orion Nebula is more chemically enriched via galaxy evolution than currently thought. This program will reveal the true impact of the large-scale cluster environment on disk properties and evolution, while paving the way for future wide-band RRL surveys of planet-forming disks.', 'cal_status': 'Not Ready', 'pi': 'Ryan Boyden', 'obs_start': '2025-10-21T10:10:07.100Z', 'obs_stop': '2025-10-21T12:49:37.199Z', 'obs_release_date': '2026-10-21T12:49:37.200Z', 'proj_start': '2025-09-22T08:42:58.599Z', 'proj_stop': '2025-10-21T12:49:37.199Z', 'instrument_name': 'EVLA', 'data_rights': 'LOCKED', 'calib_level': None, 'vla_configuration': 'B', 'dataproduct_type': 'visibility', 'access_estsize': 106182932000, 'num_scans': 80, 'obs_band': ['KA'], 'intents': ['OBSERVE_TARGET', 'CALIBRATE_PHASE', 'CALIBRATE_AMPLI', 'UNSPECIFIED', 'CALIBRATE_POINTING', 'SYSTEM_CONFIGURATION', 'CALIBRATE_BANDPASS', 'CALIBRATE_FLUX'], 'coIs': ['Charles Law', 'Zhi-Yun Li', 'Lauren Cleeves', 'Nicholas Ballering', 'Thomas Haworth', 'John Tobin', 'Kimberly Emig', 'Jonathan Tan'], 'alma_angular_res': None, 'num_antennas': 25, 'distance_from_query': None, 'acknowledgements': ['The National Radio Astronomy Observatory and Green Bank Observatory are facilities of the U.S. National Science Foundation operated under cooperative agreement by Associated Universities, Inc.'], 'comments': None, 'problem_severity': None, 'problem_type': None, 'problem_link': None, 'mousId': None, 'gousId': None, 'sousId': None, 'vlba_segment': None, 'segment_start': None, 'segment_stop': None, 'segment_bands': [], 'segment_size': None, 'n_execution_blocks': 14}, {'id': 'nrao:623333', 'eb_id': 623333, 'sci_prod_locator': 'uid://evla/execblock/b0e1eeff-c519-41de-9e0e-3df34119995c', 'obs_id': '25A-310.sb49268828.eb49611265.60969.38213347222', 'schedBlockName': None, 'filegroup_id': None, 'legacy_id': 'AF685', 'project_code': '25A-310', 'title': 'Resolving fuel and products of SF in a lensed dusty protocluster core at z=2.7', 'abstract': 'Here we propose a VLA+JWST joint program to simultaneously characterize the molecular gas properties and the obscured/unobscured stellar populations within a Planck-selected strongly lensed, gas-rich protocluster, J08. J08 hosts at least 11 dusty star-forming galaxies (DSFGs) all at z=2.66, within 300 kpc and total SFR > 5000 Ms/yr. J08 offers a valuable opportunity to study gas-rich environmental effects on galaxy evolution and assembly at Cosmic Noon. We seek Ka observations in B and D configuration to image the CO(1-0) line emission across this overdense field. We propose t ...
# ['25B-250', '25A-310', 'SF181025', '25A-278', '25B-283', '25A-309', 'Operations', '158_2', '24B-429', 'VLASS4.1', 'TSUB0001', 'TCAL0003', '25B-326', '25B-286', '25B-138', '25B-146', '25B-104', '25B-266', '25B-216', '25A-367', '25B-110', '25B-324', '25B-079', '25A-109', '25B-139']
#
# List of public projects:
#  6     Operations
# 7          158_2
# 9       VLASS4.1
# 10      TSUB0001
# 11      TCAL0003
# Name: project_code, dtype: object

# %%
def get_project_observations(project_codes):

    df = pd.DataFrame()
    for code in project_codes[:2]:
        project_url = f"https://data.nrao.edu/archive-service/restapi_get_paged_exec_blocks?start=0&rows=25&sort=obs_stop%20desc&project_code=%22{code}%22"
        print('url:', project_url)
        project_data = get_html(project_url)

        observations = [
            {"obs_id": p["obs_id"],
            "obs_band": p["obs_band"]}
            for p in project_data["eb_list"]
            if "obs_id" in p and "project_code" in p and "obs_band" in p
        ]
        
        df = pd.concat([df, pd.DataFrame(observations)], ignore_index=True, sort=False)

    return df

observations = get_project_observations(project_codes)
print(observations)
# Out:
# url: https://data.nrao.edu/archive-service/restapi_get_paged_exec_blocks?start=0&rows=25&sort=obs_stop%20desc&project_code=%2225B-250%22
# url: https://data.nrao.edu/archive-service/restapi_get_paged_exec_blocks?start=0&rows=25&sort=obs_stop%20desc&project_code=%2225A-310%22
#                                               obs_id obs_band
# 0   25B-250.sb49363256.eb49611267.60969.423685601854     [KA]
# 1    25B-250.sb49363115.eb49611263.60969.26939707176     [KA]
# 2    25B-250.sb49363256.eb49605086.60967.44715115741     [KA]
# 3    25B-250.sb49362732.eb49604915.60967.27364846064      [K]
# 4    25B-250.sb49362855.eb49604897.60966.45654993056      [K]
# 5   25B-250.sb49362597.eb49569883.60955.515199421294      [K]
# 6   25B-250.sb49362732.eb49569527.60953.313976840276      [K]
# 7   25B-250.sb49362732.eb49565159.60950.328320706016      [K]
# 8     25B-250.sb49362855.eb49557156.60948.4727197801      [K]
# 9    25B-250.sb49363115.eb49549282.60943.35614350694     [KA]
# 10   25B-250.sb49362855.eb49547736.60941.51161931713      [K]
# 11   25B-250.sb49362732.eb49547732.60941.36265473379      [K]
# 12   25B-250.sb49362855.eb49543989.60940.54882733796      [K]
# 13   25B-250.sb49362732.eb49543985.60940.36317023148      [K]
# 14   25A-310.sb49268828.eb49611265.60969.38213347222     [KA]
# 15   25A-310.sb49268828.eb49569561.60954.45835519676     [KA]
# 16  25A-310.sb49268828.eb49569556.60954.416629444444     [KA]
# 17   25A-310.sb49268828.eb49549284.60943.46696909722     [KA]
# 18   25A-310.sb49268828.eb49549179.60942.48157337963     [KA]

# %% [markdown]
# ### Observations in Bands of Interest

# %%
target_bands = {"KA", "Q"}  # use a set for faster lookup
interest_obs = observations[observations["obs_band"].apply(lambda x: any(b in target_bands for b in x))]

print(interest_obs)
# Out:
#                                               obs_id obs_band
# 0   25B-250.sb49363256.eb49611267.60969.423685601854     [KA]
# 1    25B-250.sb49363115.eb49611263.60969.26939707176     [KA]
# 2    25B-250.sb49363256.eb49605086.60967.44715115741     [KA]
# 9    25B-250.sb49363115.eb49549282.60943.35614350694     [KA]
# 14   25A-310.sb49268828.eb49611265.60969.38213347222     [KA]
# 15   25A-310.sb49268828.eb49569561.60954.45835519676     [KA]
# 16  25A-310.sb49268828.eb49569556.60954.416629444444     [KA]
# 17   25A-310.sb49268828.eb49549284.60943.46696909722     [KA]
# 18   25A-310.sb49268828.eb49549179.60942.48157337963     [KA]

# %%
interest_obs_id = interest_obs["obs_id"].iloc[0]
print(interest_obs_id)
observation_url = f"https://data.nrao.edu/archive-service/restapi_product_details_view?sdm_id={interest_obs_id}"

obs_data = get_html(observation_url)
print(json.dumps(obs_data, indent=2))
# Out:
# 25B-250.sb49363256.eb49611267.60969.423685601854
# {
#   "details": {
#     "dataset_title": "25B-250.sb49363256.eb49611267.60969.423685601854",
#     "execution_blocks": [
#       {
#         "sdm_id": "25B-250.sb49363256.eb49611267.60969.423685601854",
#         "project_code": "25B-250",
#         "obs_start": "2025-10-21 10:10:07.100",
#         "obs_stop": 60969.534458333335,
#         "cal_status": "Ready",
#         "band_code": "KA",
#         "num_antennas": 25,
#         "configuration": "B",
#         "instrument_name": "EVLA",
#         "alma_ous_id": null,
#         "legacy_id": "AB1981",
#         "access_estsize": 106182932000,
#         "configurations": [
#           {
#             "observation_configuration_id": "418459",
#             "observation_configuration_number": "0",
#             "band": "Ka",
#             "aggregate_bandwidth": 2557772222.222229,
#             "min_frequency": 28095733741.77062,
#             "max_frequency": 36663452651.459946,
#             "min_spec_resolution": 100000.0,
#             "max_spec_resolution": 1000000.0,
#             "spws": [
#               {
#                 "spw_name": "EVLA_KA#A1C1#0",
#                 "obs_spw_number": 0,
#                 "center_frequency": 33829178591.273125,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 128,
#                 "spectral_resolution": 1000000.0
#               },
#               {
#                 "spw_name": "EVLA_KA#A1C1#1",
#                 "obs_spw_number": 1,
#                 "center_frequency": 34469178591.273125,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 128,
#                 "spectral_resolution": 1000000.0
#               },
#               {
#                 "spw_name": "EVLA_KA#A1C1#2",
#                 "obs_spw_number": 2,
#                 "center_frequency": 34725178591.273125,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 128,
#                 "spectral_resolution": 1000000.0
#               },
#               {
#                 "spw_name": "EVLA_KA#A1C1#3",
#                 "obs_spw_number": 3,
#                 "center_frequency": 34085178591.273125,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 128,
#                 "spectral_resolution": 1000000.0
#               },
#               {
#                 "spw_name": "EVLA_KA#A1C1#4",
#                 "obs_spw_number": 4,
#                 "center_frequency": 34596734146.82868,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 1152,
#                 "spectral_resolution": 111111.11111111112
#               },
#               {
#                 "spw_name": "EVLA_KA#A2C2#5",
#                 "obs_spw_number": 5,
#                 "center_frequency": 36343452651.459946,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 128,
#                 "spectral_resolution": 1000000.0
#               },
#               {
#                 "spw_name": "EVLA_KA#A2C2#6",
#                 "obs_spw_number": 6,
#                 "center_frequency": 36599452651.459946,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 128,
#                 "spectral_resolution": 1000000.0
#               },
#               {
#                 "spw_name": "EVLA_KA#A2C2#7",
#                 "obs_spw_number": 7,
#                 "center_frequency": 35831452651.459946,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 128,
#                 "spectral_resolution": 1000000.0
#               },
#               {
#                 "spw_name": "EVLA_KA#A2C2#8",
#                 "obs_spw_number": 8,
#                 "center_frequency": 36471008207.0155,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 1152,
#                 "spectral_resolution": 111111.11111111112
#               },
#               {
#                 "spw_name": "EVLA_KA#B1D1#9",
#                 "obs_spw_number": 9,
#                 "center_frequency": 29567733741.77062,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 128,
#                 "spectral_resolution": 1000000.0
#               },
#               {
#                 "spw_name": "EVLA_KA#B1D1#10",
#                 "obs_spw_number": 10,
#                 "center_frequency": 28159733741.77062,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 128,
#                 "spectral_resolution": 1000000.0
#               },
#               {
#                 "spw_name": "EVLA_KA#B1D1#11",
#                 "obs_spw_number": 11,
#                 "center_frequency": 29823733741.77062,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 128,
#                 "spectral_resolution": 1000000.0
#               },
#               {
#                 "spw_name": "EVLA_KA#B1D1#12",
#                 "obs_spw_number": 12,
#                 "center_frequency": 28415733741.77062,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 128,
#                 "spectral_resolution": 1000000.0
#               },
#               {
#                 "spw_name": "EVLA_KA#B1D1#13",
#                 "obs_spw_number": 13,
#                 "center_frequency": 28671733741.77062,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 128,
#                 "spectral_resolution": 1000000.0
#               },
#               {
#                 "spw_name": "EVLA_KA#B1D1#14",
#                 "obs_spw_number": 14,
#                 "center_frequency": 29695289297.326176,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 1152,
#                 "spectral_resolution": 111111.11111111112
#               },
#               {
#                 "spw_name": "EVLA_KA#B1D1#15",
#                 "obs_spw_number": 15,
#                 "center_frequency": 28287289297.326176,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 1152,
#                 "spectral_resolution": 111111.11111111112
#               },
#               {
#                 "spw_name": "EVLA_KA#B2D2#16",
#                 "obs_spw_number": 16,
#                 "center_frequency": 31100740586.79512,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 128,
#                 "spectral_resolution": 1000000.0
#               },
#               {
#                 "spw_name": "EVLA_KA#B2D2#17",
#                 "obs_spw_number": 17,
#                 "center_frequency": 31356740586.79512,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 128,
#                 "spectral_resolution": 1000000.0
#               },
#               {
#                 "spw_name": "EVLA_KA#B2D2#18",
#                 "obs_spw_number": 18,
#                 "center_frequency": 32124740586.79512,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 128,
#                 "spectral_resolution": 1000000.0
#               },
#               {
#                 "spw_name": "EVLA_KA#B2D2#19",
#                 "obs_spw_number": 19,
#                 "center_frequency": 31228290586.79512,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 1280,
#                 "spectral_resolution": 100000.0
#               }
#             ],
#             "target_durs": [
#               {
#                 "target_name": "3C147",
#                 "ra": 85.65057465185124,
#                 "dec": 49.85200932178193,
#                 "duration": 0.0027702546285581775
#               },
#               {
#                 "target_name": "J0319+4130",
#                 "ra": 49.95066709068327,
#                 "dec": 41.51169529027947,
#                 "duration": 0.006232638887013309
#               },
#               {
#                 "target_name": "J0541-0541",
#                 "ra": 85.40868076878155,
#                 "dec": -5.697063444412095,
#                 "duration": 0.020083333387447055
#               },
#               {
#                 "target_name": "ONCpoint",
#                 "ra": 83.81874999965639,
#                 "dec": -5.391777780179309,
#                 "duration": 0.056097222164680716
#               }
#             ]
#           },
#           {
#             "observation_configuration_id": "418460",
#             "observation_configuration_number": "1",
#             "band": "X",
#             "aggregate_bandwidth": 256000000.0,
#             "min_frequency": 8333000000.0,
#             "max_frequency": 8589000000.0,
#             "min_spec_resolution": 2000000.0,
#             "max_spec_resolution": 2000000.0,
#             "spws": [
#               {
#                 "spw_name": "EVLA_X#A0C0#20",
#                 "obs_spw_number": 20,
#                 "center_frequency": 8397000000.0,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 64,
#                 "spectral_resolution": 2000000.0
#               },
#               {
#                 "spw_name": "EVLA_X#B0D0#21",
#                 "obs_spw_number": 21,
#                 "center_frequency": 8525000000.0,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 64,
#                 "spectral_resolution": 2000000.0
#               }
#             ],
#             "target_durs": [
#               {
#                 "target_name": "J0319+4130",
#                 "ra": 49.95066709068327,
#                 "dec": 41.51169529027947,
#                 "duration": 0.0025376157427672297
#               },
#               {
#                 "target_name": "J0541+5312",
#                 "ra": 85.3173918100834,
#                 "dec": 53.20689837398182,
#                 "duration": 0.0024988425939227454
#               },
#               {
#                 "target_name": "J0541-0541",
#                 "ra": 85.40868076878155,
#                 "dec": -5.697063444412095,
#                 "duration": 0.005709490746085066
#               }
#             ]
#           }
#         ],
#         "scan_rows": [
#           {
#             "scan_num": "26",
#             "subscan_num": "1",
#             "target_name": "ONCpoint",
#             "starttime": "2025-10-21 11:07:04.050",
#             "endtime": "2025-10-21 11:10:03.550",
#             "duration": 0.002077546298096422,
#             "integration_time": 3.042,
#             "band": "Ka",
#             "polarizations": "RR, LL",
#             "ra": 83.81874999965639,
#             "dec": -5.391777780179309,
#             "observation_configuration_number": "0",
#             "observation_configuration_id": "418459",
#             "intent": "OBSERVE_TARGET",
#             "subscan_id": "113108097",
#             "aggregate_bandwidth": 2557772222.222229,
#             "min_frequency": 28095733741.77062,
#             "max_frequency": 36663452651.459946,
#             "spws": [
#               {
#                 "spw_name": "EVLA_KA#A1C1#0",
#                 "obs_spw_number": 0,
#                 "center_frequency": 33829178591.273125,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 128,
#                 "spectral_resolution": 1000000.0
#               },
#               {
#                 "spw_name": "EVLA_KA#A1C1#1",
#                 "obs_spw_number": 1,
#                 "center_frequency": 34469178591.273125,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 128,
#                 "spectral_resolution": 1000000.0
#               },
#               {
#                 "spw_name": "EVLA_KA#A1C1#2",
#                 "obs_spw_number": 2,
#                 "center_frequency": 34725178591.273125,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 128,
#                 "spectral_resolution": 1000000.0
#               },
#               {
#                 "spw_name": "EVLA_KA#A1C1#3",
#                 "obs_spw_number": 3,
#                 "center_frequency": 34085178591.273125,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 128,
#                 "spectral_resolution": 1000000.0
#               },
#               {
#                 "spw_name": "EVLA_KA#A1C1#4",
#                 "obs_spw_number": 4,
#                 "center_frequency": 34596734146.82868,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 1152,
#                 "spectral_resolution": 111111.11111111112
#               },
#               {
#                 "spw_name": "EVLA_KA#A2C2#5",
#                 "obs_spw_number": 5,
#                 "center_frequency": 36343452651.459946,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 128,
#                 "spectral_resolution": 1000000.0
#               },
#               {
#                 "spw_name": "EVLA_KA#A2C2#6",
#                 "obs_spw_number": 6,
#                 "center_frequency": 36599452651.459946,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 128,
#                 "spectral_resolution": 1000000.0
#               },
#               {
#                 "spw_name": "EVLA_KA#A2C2#7",
#                 "obs_spw_number": 7,
#                 "center_frequency": 35831452651.459946,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 128,
#                 "spectral_resolution": 1000000.0
#               },
#               {
#                 "spw_name": "EVLA_KA#A2C2#8",
#                 "obs_spw_number": 8,
#                 "center_frequency": 36471008207.0155,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 1152,
#                 "spectral_resolution": 111111.11111111112
#               },
#               {
#                 "spw_name": "EVLA_KA#B1D1#9",
#                 "obs_spw_number": 9,
#                 "center_frequency": 29567733741.77062,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 128,
#                 "spectral_resolution": 1000000.0
#               },
#               {
#                 "spw_name": "EVLA_KA#B1D1#10",
#                 "obs_spw_number": 10,
#                 "center_frequency": 28159733741.77062,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 128,
#                 "spectral_resolution": 1000000.0
#               },
#               {
#                 "spw_name": "EVLA_KA#B1D1#11",
#                 "obs_spw_number": 11,
#                 "center_frequency": 29823733741.77062,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 128,
#                 "spectral_resolution": 1000000.0
#               },
#               {
#                 "spw_name": "EVLA_KA#B1D1#12",
#                 "obs_spw_number": 12,
#                 "center_frequency": 28415733741.77062,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 128,
#                 "spectral_resolution": 1000000.0
#               },
#               {
#                 "spw_name": "EVLA_KA#B1D1#13",
#                 "obs_spw_number": 13,
#                 "center_frequency": 28671733741.77062,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 128,
#                 "spectral_resolution": 1000000.0
#               },
#               {
#                 "spw_name": "EVLA_KA#B1D1#14",
#                 "obs_spw_number": 14,
#                 "center_frequency": 29695289297.326176,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 1152,
#                 "spectral_resolution": 111111.11111111112
#               },
#               {
#                 "spw_name": "EVLA_KA#B1D1#15",
#                 "obs_spw_number": 15,
#                 "center_frequency": 28287289297.326176,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 1152,
#                 "spectral_resolution": 111111.11111111112
#               },
#               {
#                 "spw_name": "EVLA_KA#B2D2#16",
#                 "obs_spw_number": 16,
#                 "center_frequency": 31100740586.79512,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 128,
#                 "spectral_resolution": 1000000.0
#               },
#               {
#                 "spw_name": "EVLA_KA#B2D2#17",
#                 "obs_spw_number": 17,
#                 "center_frequency": 31356740586.79512,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 128,
#                 "spectral_resolution": 1000000.0
#               },
#               {
#                 "spw_name": "EVLA_KA#B2D2#18",
#                 "obs_spw_number": 18,
#                 "center_frequency": 32124740586.79512,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 128,
#                 "spectral_resolution": 1000000.0
#               },
#               {
#                 "spw_name": "EVLA_KA#B2D2#19",
#                 "obs_spw_number": 19,
#                 "center_frequency": 31228290586.79512,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 1280,
#                 "spectral_resolution": 100000.0
#               }
#             ]
#           },
#           {
#             "scan_num": "27",
#             "subscan_num": "1",
#             "target_name": "J0541-0541",
#             "starttime": "2025-10-21 11:10:03.550",
#             "endtime": "2025-10-21 11:11:03.400",
#             "duration": 0.000692708337737713,
#             "integration_time": 3.15,
#             "band": "Ka",
#             "polarizations": "RR, LL",
#             "ra": 85.40868076878155,
#             "dec": -5.697063444412095,
#             "observation_configuration_number": "0",
#             "observation_configuration_id": "418459",
#             "intent": "CALIBRATE_PHASE CALIBRATE_AMPLI",
#             "subscan_id": "113108098",
#             "aggregate_bandwidth": 2557772222.222229,
#             "min_frequency": 28095733741.77062,
#             "max_frequency": 36663452651.459946,
#             "spws": [
#               {
#                 "spw_name": "EVLA_KA#A1C1#0",
#                 "obs_spw_number": 0,
#                 "center_frequency": 33829178591.273125,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 128,
#                 "spectral_resolution": 1000000.0
#               },
#               {
#                 "spw_name": "EVLA_KA#A1C1#1",
#                 "obs_spw_number": 1,
#                 "center_frequency": 34469178591.273125,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 128,
#                 "spectral_resolution": 1000000.0
#               },
#               {
#                 "spw_name": "EVLA_KA#A1C1#2",
#                 "obs_spw_number": 2,
#                 "center_frequency": 34725178591.273125,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 128,
#                 "spectral_resolution": 1000000.0
#               },
#               {
#                 "spw_name": "EVLA_KA#A1C1#3",
#                 "obs_spw_number": 3,
#                 "center_frequency": 34085178591.273125,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 128,
#                 "spectral_resolution": 1000000.0
#               },
#               {
#                 "spw_name": "EVLA_KA#A1C1#4",
#                 "obs_spw_number": 4,
#                 "center_frequency": 34596734146.82868,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 1152,
#                 "spectral_resolution": 111111.11111111112
#               },
#               {
#                 "spw_name": "EVLA_KA#A2C2#5",
#                 "obs_spw_number": 5,
#                 "center_frequency": 36343452651.459946,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 128,
#                 "spectral_resolution": 1000000.0
#               },
#               {
#                 "spw_name": "EVLA_KA#A2C2#6",
#                 "obs_spw_number": 6,
#                 "center_frequency": 36599452651.459946,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 128,
#                 "spectral_resolution": 1000000.0
#               },
#               {
#                 "spw_name": "EVLA_KA#A2C2#7",
#                 "obs_spw_number": 7,
#                 "center_frequency": 35831452651.459946,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 128,
#                 "spectral_resolution": 1000000.0
#               },
#               {
#                 "spw_name": "EVLA_KA#A2C2#8",
#                 "obs_spw_number": 8,
#                 "center_frequency": 36471008207.0155,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 1152,
#                 "spectral_resolution": 111111.11111111112
#               },
#               {
#                 "spw_name": "EVLA_KA#B1D1#9",
#                 "obs_spw_number": 9,
#                 "center_frequency": 29567733741.77062,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 128,
#                 "spectral_resolution": 1000000.0
#               },
#               {
#                 "spw_name": "EVLA_KA#B1D1#10",
#                 "obs_spw_number": 10,
#                 "center_frequency": 28159733741.77062,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 128,
#                 "spectral_resolution": 1000000.0
#               },
#               {
#                 "spw_name": "EVLA_KA#B1D1#11",
#                 "obs_spw_number": 11,
#                 "center_frequency": 29823733741.77062,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 128,
#                 "spectral_resolution": 1000000.0
#               },
#               {
#                 "spw_name": "EVLA_KA#B1D1#12",
#                 "obs_spw_number": 12,
#                 "center_frequency": 28415733741.77062,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 128,
#                 "spectral_resolution": 1000000.0
#               },
#               {
#                 "spw_name": "EVLA_KA#B1D1#13",
#                 "obs_spw_number": 13,
#                 "center_frequency": 28671733741.77062,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 128,
#                 "spectral_resolution": 1000000.0
#               },
#               {
#                 "spw_name": "EVLA_KA#B1D1#14",
#                 "obs_spw_number": 14,
#                 "center_frequency": 29695289297.326176,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 1152,
#                 "spectral_resolution": 111111.11111111112
#               },
#               {
#                 "spw_name": "EVLA_KA#B1D1#15",
#                 "obs_spw_number": 15,
#                 "center_frequency": 28287289297.326176,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 1152,
#                 "spectral_resolution": 111111.11111111112
#               },
#               {
#                 "spw_name": "EVLA_KA#B2D2#16",
#                 "obs_spw_number": 16,
#                 "center_frequency": 31100740586.79512,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 128,
#                 "spectral_resolution": 1000000.0
#               },
#               {
#                 "spw_name": "EVLA_KA#B2D2#17",
#                 "obs_spw_number": 17,
#                 "center_frequency": 31356740586.79512,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 128,
#                 "spectral_resolution": 1000000.0
#               },
#               {
#                 "spw_name": "EVLA_KA#B2D2#18",
#                 "obs_spw_number": 18,
#                 "center_frequency": 32124740586.79512,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 128,
#                 "spectral_resolution": 1000000.0
#               },
#               {
#                 "spw_name": "EVLA_KA#B2D2#19",
#                 "obs_spw_number": 19,
#                 "center_frequency": 31228290586.79512,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 1280,
#                 "spectral_resolution": 100000.0
#               }
#             ]
#           },
#           {
#             "scan_num": "28",
#             "subscan_num": "1",
#             "target_name": "ONCpoint",
#             "starttime": "2025-10-21 11:11:03.400",
#             "endtime": "2025-10-21 11:14:02.900",
#             "duration": 0.0020775462908204645,
#             "integration_time": 3.095,
#             "band": "Ka",
#             "polarizations": "RR, LL",
#             "ra": 83.81874999965639,
#             "dec": -5.391777780179309,
#             "observation_configuration_number": "0",
#             "observation_configuration_id": "418459",
#             "intent": "OBSERVE_TARGET",
#             "subscan_id": "113108099",
#             "aggregate_bandwidth": 2557772222.222229,
#             "min_frequency": 28095733741.77062,
#             "max_frequency": 36663452651.459946,
#             "spws": [
#               {
#                 "spw_name": "EVLA_KA#A1C1#0",
#                 "obs_spw_number": 0,
#                 "center_frequency": 33829178591.273125,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 128,
#                 "spectral_resolution": 1000000.0
#               },
#               {
#                 "spw_name": "EVLA_KA#A1C1#1",
#                 "obs_spw_number": 1,
#                 "center_frequency": 34469178591.273125,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 128,
#                 "spectral_resolution": 1000000.0
#               },
#               {
#                 "spw_name": "EVLA_KA#A1C1#2",
#                 "obs_spw_number": 2,
#                 "center_frequency": 34725178591.273125,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 128,
#                 "spectral_resolution": 1000000.0
#               },
#               {
#                 "spw_name": "EVLA_KA#A1C1#3",
#                 "obs_spw_number": 3,
#                 "center_frequency": 34085178591.273125,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 128,
#                 "spectral_resolution": 1000000.0
#               },
#               {
#                 "spw_name": "EVLA_KA#A1C1#4",
#                 "obs_spw_number": 4,
#                 "center_frequency": 34596734146.82868,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 1152,
#                 "spectral_resolution": 111111.11111111112
#               },
#               {
#                 "spw_name": "EVLA_KA#A2C2#5",
#                 "obs_spw_number": 5,
#                 "center_frequency": 36343452651.459946,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 128,
#                 "spectral_resolution": 1000000.0
#               },
#               {
#                 "spw_name": "EVLA_KA#A2C2#6",
#                 "obs_spw_number": 6,
#                 "center_frequency": 36599452651.459946,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 128,
#                 "spectral_resolution": 1000000.0
#               },
#               {
#                 "spw_name": "EVLA_KA#A2C2#7",
#                 "obs_spw_number": 7,
#                 "center_frequency": 35831452651.459946,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 128,
#                 "spectral_resolution": 1000000.0
#               },
#               {
#                 "spw_name": "EVLA_KA#A2C2#8",
#                 "obs_spw_number": 8,
#                 "center_frequency": 36471008207.0155,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 1152,
#                 "spectral_resolution": 111111.11111111112
#               },
#               {
#                 "spw_name": "EVLA_KA#B1D1#9",
#                 "obs_spw_number": 9,
#                 "center_frequency": 29567733741.77062,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 128,
#                 "spectral_resolution": 1000000.0
#               },
#               {
#                 "spw_name": "EVLA_KA#B1D1#10",
#                 "obs_spw_number": 10,
#                 "center_frequency": 28159733741.77062,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 128,
#                 "spectral_resolution": 1000000.0
#               },
#               {
#                 "spw_name": "EVLA_KA#B1D1#11",
#                 "obs_spw_number": 11,
#                 "center_frequency": 29823733741.77062,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 128,
#                 "spectral_resolution": 1000000.0
#               },
#               {
#                 "spw_name": "EVLA_KA#B1D1#12",
#                 "obs_spw_number": 12,
#                 "center_frequency": 28415733741.77062,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 128,
#                 "spectral_resolution": 1000000.0
#               },
#               {
#                 "spw_name": "EVLA_KA#B1D1#13",
#                 "obs_spw_number": 13,
#                 "center_frequency": 28671733741.77062,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 128,
#                 "spectral_resolution": 1000000.0
#               },
#               {
#                 "spw_name": "EVLA_KA#B1D1#14",
#                 "obs_spw_number": 14,
#                 "center_frequency": 29695289297.326176,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 1152,
#                 "spectral_resolution": 111111.11111111112
#               },
#               {
#                 "spw_name": "EVLA_KA#B1D1#15",
#                 "obs_spw_number": 15,
#                 "center_frequency": 28287289297.326176,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 1152,
#                 "spectral_resolution": 111111.11111111112
#               },
#               {
#                 "spw_name": "EVLA_KA#B2D2#16",
#                 "obs_spw_number": 16,
#                 "center_frequency": 31100740586.79512,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 128,
#                 "spectral_resolution": 1000000.0
#               },
#               {
#                 "spw_name": "EVLA_KA#B2D2#17",
#                 "obs_spw_number": 17,
#                 "center_frequency": 31356740586.79512,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 128,
#                 "spectral_resolution": 1000000.0
#               },
#               {
#                 "spw_name": "EVLA_KA#B2D2#18",
#                 "obs_spw_number": 18,
#                 "center_frequency": 32124740586.79512,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 128,
#                 "spectral_resolution": 1000000.0
#               },
#               {
#                 "spw_name": "EVLA_KA#B2D2#19",
#                 "obs_spw_number": 19,
#                 "center_frequency": 31228290586.79512,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 1280,
#                 "spectral_resolution": 100000.0
#               }
#             ]
#           },
#           {
#             "scan_num": "29",
#             "subscan_num": "1",
#             "target_name": "J0541-0541",
#             "starttime": "2025-10-21 11:14:02.900",
#             "endtime": "2025-10-21 11:15:02.750",
#             "duration": 0.000692708337737713,
#             "integration_time": 3.15,
#             "band": "Ka",
#             "polarizations": "RR, LL",
#             "ra": 85.40868076878155,
#             "dec": -5.697063444412095,
#             "observation_configuration_number": "0",
#             "observation_configuration_id": "418459",
#             "intent": "CALIBRATE_PHASE CALIBRATE_AMPLI",
#             "subscan_id": "113108100",
#             "aggregate_bandwidth": 2557772222.222229,
#             "min_frequency": 28095733741.77062,
#             "max_frequency": 36663452651.459946,
#             "spws": [
#               {
#                 "spw_name": "EVLA_KA#A1C1#0",
#                 "obs_spw_number": 0,
#                 "center_frequency": 33829178591.273125,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 128,
#                 "spectral_resolution": 1000000.0
#               },
#               {
#                 "spw_name": "EVLA_KA#A1C1#1",
#                 "obs_spw_number": 1,
#                 "center_frequency": 34469178591.273125,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 128,
#                 "spectral_resolution": 1000000.0
#               },
#               {
#                 "spw_name": "EVLA_KA#A1C1#2",
#                 "obs_spw_number": 2,
#                 "center_frequency": 34725178591.273125,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 128,
#                 "spectral_resolution": 1000000.0
#               },
#               {
#                 "spw_name": "EVLA_KA#A1C1#3",
#                 "obs_spw_number": 3,
#                 "center_frequency": 34085178591.273125,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 128,
#                 "spectral_resolution": 1000000.0
#               },
#               {
#                 "spw_name": "EVLA_KA#A1C1#4",
#                 "obs_spw_number": 4,
#                 "center_frequency": 34596734146.82868,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 1152,
#                 "spectral_resolution": 111111.11111111112
#               },
#               {
#                 "spw_name": "EVLA_KA#A2C2#5",
#                 "obs_spw_number": 5,
#                 "center_frequency": 36343452651.459946,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 128,
#                 "spectral_resolution": 1000000.0
#               },
#               {
#                 "spw_name": "EVLA_KA#A2C2#6",
#                 "obs_spw_number": 6,
#                 "center_frequency": 36599452651.459946,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 128,
#                 "spectral_resolution": 1000000.0
#               },
#               {
#                 "spw_name": "EVLA_KA#A2C2#7",
#                 "obs_spw_number": 7,
#                 "center_frequency": 35831452651.459946,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 128,
#                 "spectral_resolution": 1000000.0
#               },
#               {
#                 "spw_name": "EVLA_KA#A2C2#8",
#                 "obs_spw_number": 8,
#                 "center_frequency": 36471008207.0155,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 1152,
#                 "spectral_resolution": 111111.11111111112
#               },
#               {
#                 "spw_name": "EVLA_KA#B1D1#9",
#                 "obs_spw_number": 9,
#                 "center_frequency": 29567733741.77062,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 128,
#                 "spectral_resolution": 1000000.0
#               },
#               {
#                 "spw_name": "EVLA_KA#B1D1#10",
#                 "obs_spw_number": 10,
#                 "center_frequency": 28159733741.77062,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 128,
#                 "spectral_resolution": 1000000.0
#               },
#               {
#                 "spw_name": "EVLA_KA#B1D1#11",
#                 "obs_spw_number": 11,
#                 "center_frequency": 29823733741.77062,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 128,
#                 "spectral_resolution": 1000000.0
#               },
#               {
#                 "spw_name": "EVLA_KA#B1D1#12",
#                 "obs_spw_number": 12,
#                 "center_frequency": 28415733741.77062,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 128,
#                 "spectral_resolution": 1000000.0
#               },
#               {
#                 "spw_name": "EVLA_KA#B1D1#13",
#                 "obs_spw_number": 13,
#                 "center_frequency": 28671733741.77062,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 128,
#                 "spectral_resolution": 1000000.0
#               },
#               {
#                 "spw_name": "EVLA_KA#B1D1#14",
#                 "obs_spw_number": 14,
#                 "center_frequency": 29695289297.326176,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 1152,
#                 "spectral_resolution": 111111.11111111112
#               },
#               {
#                 "spw_name": "EVLA_KA#B1D1#15",
#                 "obs_spw_number": 15,
#                 "center_frequency": 28287289297.326176,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 1152,
#                 "spectral_resolution": 111111.11111111112
#               },
#               {
#                 "spw_name": "EVLA_KA#B2D2#16",
#                 "obs_spw_number": 16,
#                 "center_frequency": 31100740586.79512,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 128,
#                 "spectral_resolution": 1000000.0
#               },
#               {
#                 "spw_name": "EVLA_KA#B2D2#17",
#                 "obs_spw_number": 17,
#                 "center_frequency": 31356740586.79512,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 128,
#                 "spectral_resolution": 1000000.0
#               },
#               {
#                 "spw_name": "EVLA_KA#B2D2#18",
#                 "obs_spw_number": 18,
#                 "center_frequency": 32124740586.79512,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 128,
#                 "spectral_resolution": 1000000.0
#               },
#               {
#                 "spw_name": "EVLA_KA#B2D2#19",
#                 "obs_spw_number": 19,
#                 "center_frequency": 31228290586.79512,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 1280,
#                 "spectral_resolution": 100000.0
#               }
#             ]
#           },
#           {
#             "scan_num": "30",
#             "subscan_num": "1",
#             "target_name": "ONCpoint",
#             "starttime": "2025-10-21 11:15:02.750",
#             "endtime": "2025-10-21 11:18:02.250",
#             "duration": 0.002077546283544507,
#             "integration_time": 3.042,
#             "band": "Ka",
#             "polarizations": "RR, LL",
#             "ra": 83.81874999965639,
#             "dec": -5.391777780179309,
#             "observation_configuration_number": "0",
#             "observation_configuration_id": "418459",
#             "intent": "OBSERVE_TARGET",
#             "subscan_id": "113108101",
#             "aggregate_bandwidth": 2557772222.222229,
#             "min_frequency": 28095733741.77062,
#             "max_frequency": 36663452651.459946,
#             "spws": [
#               {
#                 "spw_name": "EVLA_KA#A1C1#0",
#                 "obs_spw_number": 0,
#                 "center_frequency": 33829178591.273125,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 128,
#                 "spectral_resolution": 1000000.0
#               },
#               {
#                 "spw_name": "EVLA_KA#A1C1#1",
#                 "obs_spw_number": 1,
#                 "center_frequency": 34469178591.273125,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 128,
#                 "spectral_resolution": 1000000.0
#               },
#               {
#                 "spw_name": "EVLA_KA#A1C1#2",
#                 "obs_spw_number": 2,
#                 "center_frequency": 34725178591.273125,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 128,
#                 "spectral_resolution": 1000000.0
#               },
#               {
#                 "spw_name": "EVLA_KA#A1C1#3",
#                 "obs_spw_number": 3,
#                 "center_frequency": 34085178591.273125,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 128,
#                 "spectral_resolution": 1000000.0
#               },
#               {
#                 "spw_name": "EVLA_KA#A1C1#4",
#                 "obs_spw_number": 4,
#                 "center_frequency": 34596734146.82868,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 1152,
#                 "spectral_resolution": 111111.11111111112
#               },
#               {
#                 "spw_name": "EVLA_KA#A2C2#5",
#                 "obs_spw_number": 5,
#                 "center_frequency": 36343452651.459946,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 128,
#                 "spectral_resolution": 1000000.0
#               },
#               {
#                 "spw_name": "EVLA_KA#A2C2#6",
#                 "obs_spw_number": 6,
#                 "center_frequency": 36599452651.459946,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 128,
#                 "spectral_resolution": 1000000.0
#               },
#               {
#                 "spw_name": "EVLA_KA#A2C2#7",
#                 "obs_spw_number": 7,
#                 "center_frequency": 35831452651.459946,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 128,
#                 "spectral_resolution": 1000000.0
#               },
#               {
#                 "spw_name": "EVLA_KA#A2C2#8",
#                 "obs_spw_number": 8,
#                 "center_frequency": 36471008207.0155,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 1152,
#                 "spectral_resolution": 111111.11111111112
#               },
#               {
#                 "spw_name": "EVLA_KA#B1D1#9",
#                 "obs_spw_number": 9,
#                 "center_frequency": 29567733741.77062,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 128,
#                 "spectral_resolution": 1000000.0
#               },
#               {
#                 "spw_name": "EVLA_KA#B1D1#10",
#                 "obs_spw_number": 10,
#                 "center_frequency": 28159733741.77062,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 128,
#                 "spectral_resolution": 1000000.0
#               },
#               {
#                 "spw_name": "EVLA_KA#B1D1#11",
#                 "obs_spw_number": 11,
#                 "center_frequency": 29823733741.77062,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 128,
#                 "spectral_resolution": 1000000.0
#               },
#               {
#                 "spw_name": "EVLA_KA#B1D1#12",
#                 "obs_spw_number": 12,
#                 "center_frequency": 28415733741.77062,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 128,
#                 "spectral_resolution": 1000000.0
#               },
#               {
#                 "spw_name": "EVLA_KA#B1D1#13",
#                 "obs_spw_number": 13,
#                 "center_frequency": 28671733741.77062,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 128,
#                 "spectral_resolution": 1000000.0
#               },
#               {
#                 "spw_name": "EVLA_KA#B1D1#14",
#                 "obs_spw_number": 14,
#                 "center_frequency": 29695289297.326176,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 1152,
#                 "spectral_resolution": 111111.11111111112
#               },
#               {
#                 "spw_name": "EVLA_KA#B1D1#15",
#                 "obs_spw_number": 15,
#                 "center_frequency": 28287289297.326176,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 1152,
#                 "spectral_resolution": 111111.11111111112
#               },
#               {
#                 "spw_name": "EVLA_KA#B2D2#16",
#                 "obs_spw_number": 16,
#                 "center_frequency": 31100740586.79512,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 128,
#                 "spectral_resolution": 1000000.0
#               },
#               {
#                 "spw_name": "EVLA_KA#B2D2#17",
#                 "obs_spw_number": 17,
#                 "center_frequency": 31356740586.79512,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 128,
#                 "spectral_resolution": 1000000.0
#               },
#               {
#                 "spw_name": "EVLA_KA#B2D2#18",
#                 "obs_spw_number": 18,
#                 "center_frequency": 32124740586.79512,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 128,
#                 "spectral_resolution": 1000000.0
#               },
#               {
#                 "spw_name": "EVLA_KA#B2D2#19",
#                 "obs_spw_number": 19,
#                 "center_frequency": 31228290586.79512,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 1280,
#                 "spectral_resolution": 100000.0
#               }
#             ]
#           },
#           {
#             "scan_num": "31",
#             "subscan_num": "1",
#             "target_name": "J0541-0541",
#             "starttime": "2025-10-21 11:18:02.250",
#             "endtime": "2025-10-21 11:19:02.100",
#             "duration": 0.000692708337737713,
#             "integration_time": 3.15,
#             "band": "Ka",
#             "polarizations": "RR, LL",
#             "ra": 85.40868076878155,
#             "dec": -5.697063444412095,
#             "observation_configuration_number": "0",
#             "observation_configuration_id": "418459",
#             "intent": "CALIBRATE_PHASE CALIBRATE_AMPLI",
#             "subscan_id": "113108102",
#             "aggregate_bandwidth": 2557772222.222229,
#             "min_frequency": 28095733741.77062,
#             "max_frequency": 36663452651.459946,
#             "spws": [
#               {
#                 "spw_name": "EVLA_KA#A1C1#0",
#                 "obs_spw_number": 0,
#                 "center_frequency": 33829178591.273125,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 128,
#                 "spectral_resolution": 1000000.0
#               },
#               {
#                 "spw_name": "EVLA_KA#A1C1#1",
#                 "obs_spw_number": 1,
#                 "center_frequency": 34469178591.273125,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 128,
#                 "spectral_resolution": 1000000.0
#               },
#               {
#                 "spw_name": "EVLA_KA#A1C1#2",
#                 "obs_spw_number": 2,
#                 "center_frequency": 34725178591.273125,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 128,
#                 "spectral_resolution": 1000000.0
#               },
#               {
#                 "spw_name": "EVLA_KA#A1C1#3",
#                 "obs_spw_number": 3,
#                 "center_frequency": 34085178591.273125,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 128,
#                 "spectral_resolution": 1000000.0
#               },
#               {
#                 "spw_name": "EVLA_KA#A1C1#4",
#                 "obs_spw_number": 4,
#                 "center_frequency": 34596734146.82868,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 1152,
#                 "spectral_resolution": 111111.11111111112
#               },
#               {
#                 "spw_name": "EVLA_KA#A2C2#5",
#                 "obs_spw_number": 5,
#                 "center_frequency": 36343452651.459946,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 128,
#                 "spectral_resolution": 1000000.0
#               },
#               {
#                 "spw_name": "EVLA_KA#A2C2#6",
#                 "obs_spw_number": 6,
#                 "center_frequency": 36599452651.459946,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 128,
#                 "spectral_resolution": 1000000.0
#               },
#               {
#                 "spw_name": "EVLA_KA#A2C2#7",
#                 "obs_spw_number": 7,
#                 "center_frequency": 35831452651.459946,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 128,
#                 "spectral_resolution": 1000000.0
#               },
#               {
#                 "spw_name": "EVLA_KA#A2C2#8",
#                 "obs_spw_number": 8,
#                 "center_frequency": 36471008207.0155,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 1152,
#                 "spectral_resolution": 111111.11111111112
#               },
#               {
#                 "spw_name": "EVLA_KA#B1D1#9",
#                 "obs_spw_number": 9,
#                 "center_frequency": 29567733741.77062,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 128,
#                 "spectral_resolution": 1000000.0
#               },
#               {
# ...
#                 "center_frequency": 29695289297.326176,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 1152,
#                 "spectral_resolution": 111111.11111111112
#               },
#               {
#                 "spw_name": "EVLA_KA#B1D1#15",
#                 "obs_spw_number": 15,
#                 "center_frequency": 28287289297.326176,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 1152,
#                 "spectral_resolution": 111111.11111111112
#               },
#               {
#                 "spw_name": "EVLA_KA#B2D2#16",
#                 "obs_spw_number": 16,
#                 "center_frequency": 31100740586.79512,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 128,
#                 "spectral_resolution": 1000000.0
#               },
#               {
#                 "spw_name": "EVLA_KA#B2D2#17",
#                 "obs_spw_number": 17,
#                 "center_frequency": 31356740586.79512,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 128,
#                 "spectral_resolution": 1000000.0
#               },
#               {
#                 "spw_name": "EVLA_KA#B2D2#18",
#                 "obs_spw_number": 18,
#                 "center_frequency": 32124740586.79512,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 128,
#                 "spectral_resolution": 1000000.0
#               },
#               {
#                 "spw_name": "EVLA_KA#B2D2#19",
#                 "obs_spw_number": 19,
#                 "center_frequency": 31228290586.79512,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 1280,
#                 "spectral_resolution": 100000.0
#               }
#             ]
#           },
#           {
#             "scan_num": "79",
#             "subscan_num": "1",
#             "target_name": "3C147",
#             "starttime": "2025-10-21 12:45:37.850",
#             "endtime": "2025-10-21 12:47:37.550",
#             "duration": 0.0013854166681994684,
#             "integration_time": 3.069,
#             "band": "Ka",
#             "polarizations": "RR, LL",
#             "ra": 85.65057465185124,
#             "dec": 49.85200932178193,
#             "observation_configuration_number": "0",
#             "observation_configuration_id": "418459",
#             "intent": "CALIBRATE_FLUX",
#             "subscan_id": "113108176",
#             "aggregate_bandwidth": 2557772222.222229,
#             "min_frequency": 28095733741.77062,
#             "max_frequency": 36663452651.459946,
#             "spws": [
#               {
#                 "spw_name": "EVLA_KA#A1C1#0",
#                 "obs_spw_number": 0,
#                 "center_frequency": 33829178591.273125,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 128,
#                 "spectral_resolution": 1000000.0
#               },
#               {
#                 "spw_name": "EVLA_KA#A1C1#1",
#                 "obs_spw_number": 1,
#                 "center_frequency": 34469178591.273125,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 128,
#                 "spectral_resolution": 1000000.0
#               },
#               {
#                 "spw_name": "EVLA_KA#A1C1#2",
#                 "obs_spw_number": 2,
#                 "center_frequency": 34725178591.273125,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 128,
#                 "spectral_resolution": 1000000.0
#               },
#               {
#                 "spw_name": "EVLA_KA#A1C1#3",
#                 "obs_spw_number": 3,
#                 "center_frequency": 34085178591.273125,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 128,
#                 "spectral_resolution": 1000000.0
#               },
#               {
#                 "spw_name": "EVLA_KA#A1C1#4",
#                 "obs_spw_number": 4,
#                 "center_frequency": 34596734146.82868,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 1152,
#                 "spectral_resolution": 111111.11111111112
#               },
#               {
#                 "spw_name": "EVLA_KA#A2C2#5",
#                 "obs_spw_number": 5,
#                 "center_frequency": 36343452651.459946,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 128,
#                 "spectral_resolution": 1000000.0
#               },
#               {
#                 "spw_name": "EVLA_KA#A2C2#6",
#                 "obs_spw_number": 6,
#                 "center_frequency": 36599452651.459946,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 128,
#                 "spectral_resolution": 1000000.0
#               },
#               {
#                 "spw_name": "EVLA_KA#A2C2#7",
#                 "obs_spw_number": 7,
#                 "center_frequency": 35831452651.459946,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 128,
#                 "spectral_resolution": 1000000.0
#               },
#               {
#                 "spw_name": "EVLA_KA#A2C2#8",
#                 "obs_spw_number": 8,
#                 "center_frequency": 36471008207.0155,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 1152,
#                 "spectral_resolution": 111111.11111111112
#               },
#               {
#                 "spw_name": "EVLA_KA#B1D1#9",
#                 "obs_spw_number": 9,
#                 "center_frequency": 29567733741.77062,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 128,
#                 "spectral_resolution": 1000000.0
#               },
#               {
#                 "spw_name": "EVLA_KA#B1D1#10",
#                 "obs_spw_number": 10,
#                 "center_frequency": 28159733741.77062,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 128,
#                 "spectral_resolution": 1000000.0
#               },
#               {
#                 "spw_name": "EVLA_KA#B1D1#11",
#                 "obs_spw_number": 11,
#                 "center_frequency": 29823733741.77062,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 128,
#                 "spectral_resolution": 1000000.0
#               },
#               {
#                 "spw_name": "EVLA_KA#B1D1#12",
#                 "obs_spw_number": 12,
#                 "center_frequency": 28415733741.77062,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 128,
#                 "spectral_resolution": 1000000.0
#               },
#               {
#                 "spw_name": "EVLA_KA#B1D1#13",
#                 "obs_spw_number": 13,
#                 "center_frequency": 28671733741.77062,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 128,
#                 "spectral_resolution": 1000000.0
#               },
#               {
#                 "spw_name": "EVLA_KA#B1D1#14",
#                 "obs_spw_number": 14,
#                 "center_frequency": 29695289297.326176,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 1152,
#                 "spectral_resolution": 111111.11111111112
#               },
#               {
#                 "spw_name": "EVLA_KA#B1D1#15",
#                 "obs_spw_number": 15,
#                 "center_frequency": 28287289297.326176,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 1152,
#                 "spectral_resolution": 111111.11111111112
#               },
#               {
#                 "spw_name": "EVLA_KA#B2D2#16",
#                 "obs_spw_number": 16,
#                 "center_frequency": 31100740586.79512,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 128,
#                 "spectral_resolution": 1000000.0
#               },
#               {
#                 "spw_name": "EVLA_KA#B2D2#17",
#                 "obs_spw_number": 17,
#                 "center_frequency": 31356740586.79512,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 128,
#                 "spectral_resolution": 1000000.0
#               },
#               {
#                 "spw_name": "EVLA_KA#B2D2#18",
#                 "obs_spw_number": 18,
#                 "center_frequency": 32124740586.79512,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 128,
#                 "spectral_resolution": 1000000.0
#               },
#               {
#                 "spw_name": "EVLA_KA#B2D2#19",
#                 "obs_spw_number": 19,
#                 "center_frequency": 31228290586.79512,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 1280,
#                 "spectral_resolution": 100000.0
#               }
#             ]
#           },
#           {
#             "scan_num": "80",
#             "subscan_num": "1",
#             "target_name": "3C147",
#             "starttime": "2025-10-21 12:47:37.550",
#             "endtime": "2025-10-21 12:49:37.200",
#             "duration": 0.001384837960358709,
#             "integration_time": 3.068,
#             "band": "Ka",
#             "polarizations": "RR, LL",
#             "ra": 85.65057465185124,
#             "dec": 49.85200932178193,
#             "observation_configuration_number": "0",
#             "observation_configuration_id": "418459",
#             "intent": "CALIBRATE_FLUX",
#             "subscan_id": "113108177",
#             "aggregate_bandwidth": 2557772222.222229,
#             "min_frequency": 28095733741.77062,
#             "max_frequency": 36663452651.459946,
#             "spws": [
#               {
#                 "spw_name": "EVLA_KA#A1C1#0",
#                 "obs_spw_number": 0,
#                 "center_frequency": 33829178591.273125,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 128,
#                 "spectral_resolution": 1000000.0
#               },
#               {
#                 "spw_name": "EVLA_KA#A1C1#1",
#                 "obs_spw_number": 1,
#                 "center_frequency": 34469178591.273125,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 128,
#                 "spectral_resolution": 1000000.0
#               },
#               {
#                 "spw_name": "EVLA_KA#A1C1#2",
#                 "obs_spw_number": 2,
#                 "center_frequency": 34725178591.273125,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 128,
#                 "spectral_resolution": 1000000.0
#               },
#               {
#                 "spw_name": "EVLA_KA#A1C1#3",
#                 "obs_spw_number": 3,
#                 "center_frequency": 34085178591.273125,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 128,
#                 "spectral_resolution": 1000000.0
#               },
#               {
#                 "spw_name": "EVLA_KA#A1C1#4",
#                 "obs_spw_number": 4,
#                 "center_frequency": 34596734146.82868,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 1152,
#                 "spectral_resolution": 111111.11111111112
#               },
#               {
#                 "spw_name": "EVLA_KA#A2C2#5",
#                 "obs_spw_number": 5,
#                 "center_frequency": 36343452651.459946,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 128,
#                 "spectral_resolution": 1000000.0
#               },
#               {
#                 "spw_name": "EVLA_KA#A2C2#6",
#                 "obs_spw_number": 6,
#                 "center_frequency": 36599452651.459946,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 128,
#                 "spectral_resolution": 1000000.0
#               },
#               {
#                 "spw_name": "EVLA_KA#A2C2#7",
#                 "obs_spw_number": 7,
#                 "center_frequency": 35831452651.459946,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 128,
#                 "spectral_resolution": 1000000.0
#               },
#               {
#                 "spw_name": "EVLA_KA#A2C2#8",
#                 "obs_spw_number": 8,
#                 "center_frequency": 36471008207.0155,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 1152,
#                 "spectral_resolution": 111111.11111111112
#               },
#               {
#                 "spw_name": "EVLA_KA#B1D1#9",
#                 "obs_spw_number": 9,
#                 "center_frequency": 29567733741.77062,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 128,
#                 "spectral_resolution": 1000000.0
#               },
#               {
#                 "spw_name": "EVLA_KA#B1D1#10",
#                 "obs_spw_number": 10,
#                 "center_frequency": 28159733741.77062,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 128,
#                 "spectral_resolution": 1000000.0
#               },
#               {
#                 "spw_name": "EVLA_KA#B1D1#11",
#                 "obs_spw_number": 11,
#                 "center_frequency": 29823733741.77062,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 128,
#                 "spectral_resolution": 1000000.0
#               },
#               {
#                 "spw_name": "EVLA_KA#B1D1#12",
#                 "obs_spw_number": 12,
#                 "center_frequency": 28415733741.77062,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 128,
#                 "spectral_resolution": 1000000.0
#               },
#               {
#                 "spw_name": "EVLA_KA#B1D1#13",
#                 "obs_spw_number": 13,
#                 "center_frequency": 28671733741.77062,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 128,
#                 "spectral_resolution": 1000000.0
#               },
#               {
#                 "spw_name": "EVLA_KA#B1D1#14",
#                 "obs_spw_number": 14,
#                 "center_frequency": 29695289297.326176,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 1152,
#                 "spectral_resolution": 111111.11111111112
#               },
#               {
#                 "spw_name": "EVLA_KA#B1D1#15",
#                 "obs_spw_number": 15,
#                 "center_frequency": 28287289297.326176,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 1152,
#                 "spectral_resolution": 111111.11111111112
#               },
#               {
#                 "spw_name": "EVLA_KA#B2D2#16",
#                 "obs_spw_number": 16,
#                 "center_frequency": 31100740586.79512,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 128,
#                 "spectral_resolution": 1000000.0
#               },
#               {
#                 "spw_name": "EVLA_KA#B2D2#17",
#                 "obs_spw_number": 17,
#                 "center_frequency": 31356740586.79512,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 128,
#                 "spectral_resolution": 1000000.0
#               },
#               {
#                 "spw_name": "EVLA_KA#B2D2#18",
#                 "obs_spw_number": 18,
#                 "center_frequency": 32124740586.79512,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 128,
#                 "spectral_resolution": 1000000.0
#               },
#               {
#                 "spw_name": "EVLA_KA#B2D2#19",
#                 "obs_spw_number": 19,
#                 "center_frequency": 31228290586.79512,
#                 "bandwidth": 128000000.0,
#                 "num_channels": 1280,
#                 "spectral_resolution": 100000.0
#               }
#             ]
#           }
#         ],
#         "cals": [],
#         "sci_prod_locator": "uid://evla/execblock/4edace58-af9f-4123-9239-aba6f6369549",
#         "acknowledgements": [
#           "The National Radio Astronomy Observatory and Green Bank Observatory are facilities of the U.S. National Science Foundation operated under cooperative agreement by Associated Universities, Inc."
#         ]
#       }
#     ]
#   },
#   "response_msg": {
#     "success": true,
#     "code": 0,
#     "message": "Request processed"
#   }
# }
